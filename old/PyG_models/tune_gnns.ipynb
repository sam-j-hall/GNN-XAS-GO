# %%
# PyTorch
import torch
from torch.utils.data import random_split
# PyG
import torch_geometric
from torch_geometric.loader import DataLoader
from torch_geometric.utils import to_networkx
# PyTorch-Lightning
import lightning as L
from lightning.pytorch.callbacks import ModelCheckpoint, LearningRateMonitor
# Optuna
import optuna
from optuna.samplers import RandomSampler
# NetworkX
import networkx as nx
# Matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
# RDKit
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
# Local
from models import GNN_model
from dataset import XASMolDataset
from utils.functions import count_funct_groups

# %%
print(f'Pytorch version: {torch.__version__}')
print(f'PyG version: {torch_geometric.__version__}')
print(f'Lightning version: {L.__version__}')
# Out:
# Pytorch version: 2.4.1+cu124
# PyG version: 2.5.3
# Lightning version: 2.4.0

# %%
# --- Path raw directory containing the data
path = "../"
dataset = XASMolDataset(path)
# Out:
# /home/samjhall/miniconda3/envs/pyg-schnet/lib/python3.11/site-packages/torch_geometric/data/dataset.py:238: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   if osp.exists(f) and torch.load(f) != _repr(self.pre_transform):
# /home/samjhall/miniconda3/envs/pyg-schnet/lib/python3.11/site-packages/torch_geometric/data/dataset.py:246: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   if osp.exists(f) and torch.load(f) != _repr(self.pre_filter):

# %%
# --- Show detail of the dataset
print(dataset)
print('------------')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')
print('')

# --- Show details of the first molecule/graph in dataset
data = dataset[0]

print(data)
print('------------')
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')

#torch.save(dataset, './processed/test_cor_pyg.pt')
# Out:
# XASMolDataset(318)
# ------------
# Number of graphs: 318
# Number of features: 15
# Number of classes: 0
#
# Data(x=[27, 15], edge_index=[2, 72], edge_attr=[72, 5], spectrum=[200], idx=[1], smiles='c12[c:4]3[c:6]4[c:7]([H:29])[c:9]([H:30])[c:10]5[c:8]3[c:12]3[c:16]6[c:20]1[C:22]1([C:21]([H:36])=[C:19]([H:37])[C:18]6=[C:17]([H:40])[C:15]([H:38])([H:39])[C:14]36[C:13]([H:32])([C:11]5([H:31])[H:35])[O:26]6)[C:23]([H:33])([C:1]([H:27])([H:34])[C:2]23[C:3]([H:28])([C:5]4([H:41])[H:42])[O:24]3)[O:25]1', mol='R_eOH_0_eCOOH__0_eEPOXY_0_eCHO_0_eKETO_0_iOH_0_iEPOXY_0_ieEPOXY_3_2')
# ------------
# Number of nodes: 27
# Number of edges: 72
# Average node degree: 2.67
# Has isolated nodes: False
# Has self loops: False
# Is undirected: True

# %%
# --- View molecule using RDKit
IPythonConsole.drawOptions.addAtomIndices=True
IPythonConsole.drawOptions.annotationFontScale=0.8
IPythonConsole.molSize = 400,400
mol = Chem.MolFromSmiles(data.smiles)
mol

# %%
# --- Create subplot for plots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))

# --- Show graph representation of molecule
mol_graph = to_networkx(data, to_undirected=True)
nx.draw(mol_graph, ax=ax1, with_labels=True, node_size=150, font_size=8)

# --- Show molecule spectrum
ax2.plot(data.spectrum)
plt.show()

# %%
# Random seed to reproduce data split
generator = torch.Generator().manual_seed(2)
# Split dataset into train, validation and test sets
train_data, val_data, test_data = random_split(dataset, [0.75, 0.125, 0.125], generator)

print(f'Length of training data: {len(train_data)}')
print(f'Length of validation data: {len(val_data)}')
print(f'Length of testing data: {len(test_data)}')

# torch.save(test_data, './processed/test_data_coronene.pt')
# Out:
# Length of training data: 239
# Length of validation data: 40
# Length of testing data: 39

# %%
train_oh, train_cooh, train_epoxy, train_cho, train_keto = count_funct_groups(train_data)
val_oh, val_cooh, val_epoxy, val_cho, val_keto = count_funct_groups(val_data)
test_oh, test_cooh, test_epoxy, test_cho, test_keto = count_funct_groups(test_data)

print(f'Training dataset')
print(f'Epoxide: {train_epoxy:.2f}%')
print(f'Alcohol: {train_oh:.2f}%')
print(f'Carboxylic acid: {train_cooh:.2f}%')
print(f'Ketone: {train_keto:.2f}%')
print(f'Aldehyde: {train_cho:.2f}%')
print(f'---------')
print(f'Validation dataset')
print(f'Epoxide: {val_epoxy:.2f}%')
print(f'Alcohol: {val_oh:.2f}%')
print(f'Carboxylic acid: {val_cooh:.2f}%')
print(f'Ketone: {val_keto:.2f}%')
print(f'Aldehyde: {val_cho:.2f}%')
print(f'---------')
print(f'Testing dataset')
print(f'Epoxide: {test_epoxy:.2f}%')
print(f'Alcohol: {test_oh:.2f}%')
print(f'Carboxylic acid: {test_cooh:.2f}%')
print(f'Ketone: {test_keto:.2f}%')
print(f'Aldehyde: {test_cho:.2f}%')
# Out:
# Training dataset
# Epoxide: 36.39%
# Alcohol: 30.12%
# Carboxylic acid: 12.44%
# Ketone: 11.69%
# Aldehyde: 9.35%
# ---------
# Validation dataset
# Epoxide: 36.72%
# Alcohol: 29.94%
# Carboxylic acid: 11.30%
# Ketone: 10.73%
# Aldehyde: 11.30%
# ---------
# Testing dataset
# Epoxide: 37.65%
# Alcohol: 31.76%
# Carboxylic acid: 11.18%
# Ketone: 10.00%
# Aldehyde: 9.41%

# %%
# Load data splits into DataLoaders
train_loader = DataLoader(train_data, batch_size=239, shuffle=True)
val_loader = DataLoader(val_data, batch_size=40, shuffle=False)
test_loader = DataLoader(test_data, batch_size=39, shuffle=False)

print(f'Number of batches in train loader: {len(train_loader)}')
print(f'Number of batches in val loader: {len(val_loader)}')
# Out:
# Number of batches in train loader: 1
# Number of batches in val loader: 1

# %%
# Seed for reproducibility
L.seed_everything(1994, workers=True)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.set_float32_matmul_precision('high')
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# Seed set to 1994

# %%
def objective(trial):
    # Hyperparameters to optimize
    num_layers = trial.suggest_int('num_layers', 2, 5)
    hidden_channel = trial.suggest_categorical('hidden_channels', [32, 64, 128, 256])
    gnn_type = trial.suggest_categorical('gnn_type', ['gine'])
    drop_ratio  = trial.suggest_float('drop_ratio', 0.2, 0.8, step=0.05)
    learning_rate = trial.suggest_float('learning_rate', 0.001, 0.1, log=True)

    # Set model prameters
    num_tasks = 200
    # Set hidden layers based on chasen value
    in_channels = [None] * num_layers
    out_channels = [None] * num_layers
    for layer in range(num_layers):
        if layer == 0:
            in_channels[layer] = dataset.num_features
        else:
            in_channels[layer] = hidden_channel
        out_channels[layer] = hidden_channel
    heads = 1
    graph_pooling = 'mean'

    model = GNN_model(num_tasks, num_layers, in_channels, out_channels, gnn_type, 
                      heads, drop_ratio, graph_pooling, learning_rate).to(device)
    
    checkpoint_callback = ModelCheckpoint(
        filename='{val_loss:.6f}-{epoch:02d}',
        monitor='val_loss',
        mode='min',
        save_top_k=5
    )
    lr_monitor = LearningRateMonitor(logging_interval='step')

    path = './'
    logger = L.pytorch.loggers.TensorBoardLogger(save_dir=path, default_hp_metric='val_loss')
    # Lightning trainer
    trainer = L.Trainer(logger=logger,
                        callbacks=[checkpoint_callback, lr_monitor],
                        default_root_dir=path,
                        max_epochs=300, 
                        accelerator='auto',
                        log_every_n_steps=1,
                        deterministic=True)
    
    hyperparameters = dict(num_layers=num_layers, hidden_channel=hidden_channel, gnn_type=gnn_type,
                           learning_rate=learning_rate, drop_ratio=drop_ratio)
    trainer.logger.log_hyperparams(hyperparameters)
    trainer.fit(model, train_loader, val_loader)

    return trainer.callback_metrics['val_loss'].item()

# %% [markdown]
# #### Tuning

# %%
study_name = 'gine_study'
storage_name = "sqlite:///{}.db".format(study_name)
study = optuna.create_study(study_name=study_name, storage=storage_name, sampler=RandomSampler(), load_if_exists=True)
study.optimize(objective, n_trials=10)
# Out:
# [I 2025-01-12 12:28:31,354] Using an existing study with name 'gine_study' instead of creating a new one.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name              | Type       | Params | Mode
# ---------------------------------------------------------
# 0 | convs             | ModuleList | 23.1 K | train
# 1 | batch_norms       | ModuleList | 384    | train
# 2 | graph_pred_linear | Linear     | 13.0 K | train
# ---------------------------------------------------------
# 36.5 K    Trainable params
# 0         Non-trainable params
# 36.5 K    Total params
# 0.146     Total estimated model params size (MB)
# 39        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=300` reached.
# [I 2025-01-12 12:28:46,207] Trial 90 finished with value: 0.009947416372597218 and parameters: {'num_layers': 3, 'hidden_channels': 64, 'gnn_type': 'gine', 'drop_ratio': 0.75, 'learning_rate': 0.047964449192500674}. Best is trial 77 with value: 0.00849685724824667.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name              | Type       | Params | Mode
# ---------------------------------------------------------
# 0 | convs             | ModuleList | 605 K  | train
# 1 | batch_norms       | ModuleList | 2.6 K  | train
# 2 | graph_pred_linear | Linear     | 51.4 K | train
# ---------------------------------------------------------
# 658 K     Trainable params
# 0         Non-trainable params
# 658 K     Total params
# 2.636     Total estimated model params size (MB)
# 63        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=300` reached.
# [I 2025-01-12 12:29:06,516] Trial 91 finished with value: 0.010007060132920742 and parameters: {'num_layers': 5, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.75, 'learning_rate': 0.03979212287759095}. Best is trial 77 with value: 0.00849685724824667.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name              | Type       | Params | Mode
# ---------------------------------------------------------
# 0 | convs             | ModuleList | 121 K  | train
# 1 | batch_norms       | ModuleList | 1.0 K  | train
# 2 | graph_pred_linear | Linear     | 25.8 K | train
# ---------------------------------------------------------
# 147 K     Trainable params
# 0         Non-trainable params
# 147 K     Total params
# 0.592     Total estimated model params size (MB)
# 51        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=300` reached.
# [I 2025-01-12 12:29:21,450] Trial 92 finished with value: 0.009773573838174343 and parameters: {'num_layers': 4, 'hidden_channels': 128, 'gnn_type': 'gine', 'drop_ratio': 0.55, 'learning_rate': 0.011511303267921158}. Best is trial 77 with value: 0.00849685724824667.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name              | Type       | Params | Mode
# ---------------------------------------------------------
# 0 | convs             | ModuleList | 605 K  | train
# 1 | batch_norms       | ModuleList | 2.6 K  | train
# 2 | graph_pred_linear | Linear     | 51.4 K | train
# ---------------------------------------------------------
# 658 K     Trainable params
# 0         Non-trainable params
# 658 K     Total params
# 2.636     Total estimated model params size (MB)
# 63        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# ...
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=300` reached.
# [I 2025-01-12 12:30:58,187] Trial 98 finished with value: 0.009673717431724072 and parameters: {'num_layers': 2, 'hidden_channels': 64, 'gnn_type': 'gine', 'drop_ratio': 0.65, 'learning_rate': 0.048892188406806966}. Best is trial 77 with value: 0.00849685724824667.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name              | Type       | Params | Mode
# ---------------------------------------------------------
# 0 | convs             | ModuleList | 14.2 K | train
# 1 | batch_norms       | ModuleList | 256    | train
# 2 | graph_pred_linear | Linear     | 13.0 K | train
# ---------------------------------------------------------
# 27.5 K    Trainable params
# 0         Non-trainable params
# 27.5 K    Total params
# 0.110     Total estimated model params size (MB)
# 27        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=300` reached.
# [I 2025-01-12 12:31:13,894] Trial 99 finished with value: 0.010756746865808964 and parameters: {'num_layers': 2, 'hidden_channels': 64, 'gnn_type': 'gine', 'drop_ratio': 0.45, 'learning_rate': 0.0013937408962423387}. Best is trial 77 with value: 0.00849685724824667.

# %%
study_name = 'gine_study'
storage_name = "sqlite:///{}.db".format(study_name)

study = optuna.load_study(study_name=study_name, storage=storage_name)

# %%
print(f'Number of trials: {len(study.trials)}')
study.trials
# Out:
# Number of trials: 100
# [FrozenTrial(number=0, state=1, values=[0.05355086177587509], datetime_start=datetime.datetime(2025, 1, 10, 19, 7, 30, 113610), datetime_complete=datetime.datetime(2025, 1, 10, 19, 7, 28, 265464), params={'num_layers': 4, 'hidden_channels': 32, 'gnn_type': 'gine', 'drop_ratio': 0.2, 'learning_rate': 0.001947540987722974}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=1, value=None),
#  FrozenTrial(number=1, state=1, values=[0.009798971936106682], datetime_start=datetime.datetime(2025, 1, 10, 19, 7, 28, 294772), datetime_complete=datetime.datetime(2025, 1, 10, 19, 7, 47, 481977), params={'num_layers': 5, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.6000000000000001, 'learning_rate': 0.0038483658795720596}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=2, value=None),
#  FrozenTrial(number=2, state=1, values=[0.016484271734952927], datetime_start=datetime.datetime(2025, 1, 10, 19, 7, 47, 506644), datetime_complete=datetime.datetime(2025, 1, 10, 19, 8, 1, 342113), params={'num_layers': 3, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.55, 'learning_rate': 0.006118341845580137}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=3, value=None),
#  FrozenTrial(number=3, state=1, values=[0.027341922745108604], datetime_start=datetime.datetime(2025, 1, 10, 19, 8, 1, 366017), datetime_complete=datetime.datetime(2025, 1, 10, 19, 8, 16, 101486), params={'num_layers': 4, 'hidden_channels': 128, 'gnn_type': 'gine', 'drop_ratio': 0.7, 'learning_rate': 0.0017716323410545333}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=4, value=None),
#  FrozenTrial(number=4, state=1, values=[0.0100464578717947], datetime_start=datetime.datetime(2025, 1, 10, 19, 8, 16, 118820), datetime_complete=datetime.datetime(2025, 1, 10, 19, 8, 29, 362868), params={'num_layers': 2, 'hidden_channels': 32, 'gnn_type': 'gine', 'drop_ratio': 0.65, 'learning_rate': 0.0027692704450263937}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=5, value=None),
#  FrozenTrial(number=5, state=1, values=[0.008912990801036358], datetime_start=datetime.datetime(2025, 1, 10, 19, 8, 29, 387551), datetime_complete=datetime.datetime(2025, 1, 10, 19, 8, 47, 46716), params={'num_layers': 4, 'hidden_channels': 32, 'gnn_type': 'gine', 'drop_ratio': 0.2, 'learning_rate': 0.04836781198660074}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=6, value=None),
#  FrozenTrial(number=6, state=1, values=[0.009041574783623219], datetime_start=datetime.datetime(2025, 1, 10, 19, 8, 47, 66171), datetime_complete=datetime.datetime(2025, 1, 10, 19, 9, 3, 968797), params={'num_layers': 3, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.4, 'learning_rate': 0.014626133136855153}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=7, value=None),
#  FrozenTrial(number=7, state=1, values=[0.009735877625644207], datetime_start=datetime.datetime(2025, 1, 10, 19, 9, 3, 994710), datetime_complete=datetime.datetime(2025, 1, 10, 19, 9, 20, 294690), params={'num_layers': 5, 'hidden_channels': 64, 'gnn_type': 'gine', 'drop_ratio': 0.8, 'learning_rate': 0.020548069254229813}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=8, value=None),
#  FrozenTrial(number=8, state=1, values=[0.010392244905233383], datetime_start=datetime.datetime(2025, 1, 10, 19, 9, 20, 319713), datetime_complete=datetime.datetime(2025, 1, 10, 19, 9, 36, 229127), params={'num_layers': 4, 'hidden_channels': 32, 'gnn_type': 'gine', 'drop_ratio': 0.8, 'learning_rate': 0.018345467476517534}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=9, value=None),
#  FrozenTrial(number=9, state=1, values=[0.008966350927948952], datetime_start=datetime.datetime(2025, 1, 10, 19, 9, 36, 243466), datetime_complete=datetime.datetime(2025, 1, 10, 19, 9, 51, 176118), params={'num_layers': 2, 'hidden_channels': 64, 'gnn_type': 'gine', 'drop_ratio': 0.30000000000000004, 'learning_rate': 0.001455158508322158}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=10, value=None),
#  FrozenTrial(number=10, state=1, values=[0.008647292852401733], datetime_start=datetime.datetime(2025, 1, 10, 19, 10, 14, 547999), datetime_complete=datetime.datetime(2025, 1, 10, 19, 10, 33, 833578), params={'num_layers': 5, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.2, 'learning_rate': 0.003551719959557766}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=11, value=None),
#  FrozenTrial(number=11, state=1, values=[0.009535275399684906], datetime_start=datetime.datetime(2025, 1, 10, 19, 10, 33, 850647), datetime_complete=datetime.datetime(2025, 1, 10, 19, 10, 47, 739612), params={'num_layers': 3, 'hidden_channels': 32, 'gnn_type': 'gine', 'drop_ratio': 0.4, 'learning_rate': 0.009314785556239645}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=12, value=None),
#  FrozenTrial(number=12, state=1, values=[0.010311939753592014], datetime_start=datetime.datetime(2025, 1, 10, 19, 10, 47, 755082), datetime_complete=datetime.datetime(2025, 1, 10, 19, 11, 4, 643070), params={'num_layers': 3, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.4, 'learning_rate': 0.032697540626818705}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=13, value=None),
#  FrozenTrial(number=13, state=1, values=[0.008808259852230549], datetime_start=datetime.datetime(2025, 1, 10, 19, 11, 4, 660777), datetime_complete=datetime.datetime(2025, 1, 10, 19, 11, 16, 824930), params={'num_layers': 2, 'hidden_channels': 128, 'gnn_type': 'gine', 'drop_ratio': 0.4, 'learning_rate': 0.008492628692621552}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=14, value=None),
#  FrozenTrial(number=14, state=1, values=[0.016330549493432045], datetime_start=datetime.datetime(2025, 1, 10, 19, 11, 16, 843086), datetime_complete=datetime.datetime(2025, 1, 10, 19, 11, 33, 156581), params={'num_layers': 4, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.65, 'learning_rate': 0.015896480890960473}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=15, value=None),
#  FrozenTrial(number=15, state=1, values=[0.010628124698996544], datetime_start=datetime.datetime(2025, 1, 10, 19, 11, 33, 181252), datetime_complete=datetime.datetime(2025, 1, 10, 19, 11, 48, 736626), params={'num_layers': 4, 'hidden_channels': 128, 'gnn_type': 'gine', 'drop_ratio': 0.6000000000000001, 'learning_rate': 0.011869258548088488}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=16, value=None),
#  FrozenTrial(number=16, state=1, values=[0.011624759063124657], datetime_start=datetime.datetime(2025, 1, 10, 19, 11, 48, 763334), datetime_complete=datetime.datetime(2025, 1, 10, 19, 12, 7, 22939), params={'num_layers': 4, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.2, 'learning_rate': 0.08493202461560229}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=17, value=None),
#  FrozenTrial(number=17, state=1, values=[0.009221105836331844], datetime_start=datetime.datetime(2025, 1, 10, 19, 12, 7, 37575), datetime_complete=datetime.datetime(2025, 1, 10, 19, 12, 22, 424482), params={'num_layers': 3, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.65, 'learning_rate': 0.009758368534772029}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=18, value=None),
#  FrozenTrial(number=18, state=1, values=[0.010513496585190296], datetime_start=datetime.datetime(2025, 1, 10, 19, 12, 22, 439688), datetime_complete=datetime.datetime(2025, 1, 10, 19, 12, 39, 270688), params={'num_layers': 5, 'hidden_channels': 128, 'gnn_type': 'gine', 'drop_ratio': 0.35000000000000003, 'learning_rate': 0.0024787233984048134}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=19, value=None),
#  FrozenTrial(number=19, state=1, values=[0.010116564109921455], datetime_start=datetime.datetime(2025, 1, 10, 19, 12, 39, 295616), datetime_complete=datetime.datetime(2025, 1, 10, 19, 12, 54, 546043), params={'num_layers': 4, 'hidden_channels': 32, 'gnn_type': 'gine', 'drop_ratio': 0.45, 'learning_rate': 0.008978434384819179}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=20, value=None),
#  FrozenTrial(number=20, state=1, values=[0.00970152486115694], datetime_start=datetime.datetime(2025, 1, 10, 19, 12, 54, 574990), datetime_complete=datetime.datetime(2025, 1, 10, 19, 13, 14, 6950), params={'num_layers': 4, 'hidden_channels': 32, 'gnn_type': 'gine', 'drop_ratio': 0.6000000000000001, 'learning_rate': 0.05265416790534248}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=21, value=None),
#  FrozenTrial(number=21, state=1, values=[0.009419457986950874], datetime_start=datetime.datetime(2025, 1, 10, 19, 13, 14, 33867), datetime_complete=datetime.datetime(2025, 1, 10, 19, 13, 32, 863465), params={'num_layers': 4, 'hidden_channels': 64, 'gnn_type': 'gine', 'drop_ratio': 0.5, 'learning_rate': 0.03424619620909331}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=22, value=None),
#  FrozenTrial(number=22, state=1, values=[0.010075731202960014], datetime_start=datetime.datetime(2025, 1, 10, 19, 13, 32, 898236), datetime_complete=datetime.datetime(2025, 1, 10, 19, 13, 46, 955638), params={'num_layers': 2, 'hidden_channels': 32, 'gnn_type': 'gine', 'drop_ratio': 0.4, 'learning_rate': 0.07244977238247388}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=23, value=None),
#  FrozenTrial(number=23, state=1, values=[0.009114151820540428], datetime_start=datetime.datetime(2025, 1, 10, 19, 13, 46, 980602), datetime_complete=datetime.datetime(2025, 1, 10, 19, 14, 1, 862228), params={'num_layers': 2, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.7, 'learning_rate': 0.0038311564960344427}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=24, value=None),
#  FrozenTrial(number=24, state=1, values=[0.011064362712204456], datetime_start=datetime.datetime(2025, 1, 10, 19, 14, 1, 876926), datetime_complete=datetime.datetime(2025, 1, 10, 19, 14, 17, 779565), params={'num_layers': 3, 'hidden_channels': 128, 'gnn_type': 'gine', 'drop_ratio': 0.8, 'learning_rate': 0.002009362517252145}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=25, value=None),
#  FrozenTrial(number=25, state=1, values=[0.009662567637860775], datetime_start=datetime.datetime(2025, 1, 10, 19, 14, 17, 804455), datetime_complete=datetime.datetime(2025, 1, 10, 19, 14, 34, 979659), params={'num_layers': 3, 'hidden_channels': 64, 'gnn_type': 'gine', 'drop_ratio': 0.2, 'learning_rate': 0.0011544515005704314}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=26, value=None),
#  FrozenTrial(number=26, state=1, values=[0.009009486064314842], datetime_start=datetime.datetime(2025, 1, 10, 19, 14, 35, 9358), datetime_complete=datetime.datetime(2025, 1, 10, 19, 14, 50, 198661), params={'num_layers': 2, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.2, 'learning_rate': 0.0040107589337994845}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=27, value=None),
#  FrozenTrial(number=27, state=1, values=[0.04742472618818283], datetime_start=datetime.datetime(2025, 1, 10, 19, 14, 50, 213562), datetime_complete=datetime.datetime(2025, 1, 10, 19, 15, 7, 312706), params={'num_layers': 5, 'hidden_channels': 128, 'gnn_type': 'gine', 'drop_ratio': 0.55, 'learning_rate': 0.0010946172227341284}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=28, value=None),
#  FrozenTrial(number=28, state=1, values=[0.009573348797857761], datetime_start=datetime.datetime(2025, 1, 10, 19, 15, 7, 345215), datetime_complete=datetime.datetime(2025, 1, 10, 19, 15, 21, 595534), params={'num_layers': 2, 'hidden_channels': 64, 'gnn_type': 'gine', 'drop_ratio': 0.75, 'learning_rate': 0.01080504714525}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=29, value=None),
#  FrozenTrial(number=29, state=1, values=[0.059923361986875534], datetime_start=datetime.datetime(2025, 1, 10, 19, 15, 21, 627265), datetime_complete=datetime.datetime(2025, 1, 10, 19, 15, 40, 745231), params={'num_layers': 5, 'hidden_channels': 32, 'gnn_type': 'gine', 'drop_ratio': 0.25, 'learning_rate': 0.001041301002719171}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=30, value=None),
#  FrozenTrial(number=30, state=1, values=[0.00963799748569727], datetime_start=datetime.datetime(2025, 1, 12, 12, 9, 47, 761904), datetime_complete=datetime.datetime(2025, 1, 12, 12, 10, 2, 819287), params={'num_layers': 4, 'hidden_channels': 128, 'gnn_type': 'gine', 'drop_ratio': 0.5, 'learning_rate': 0.002462780362986048}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=31, value=None),
#  FrozenTrial(number=31, state=1, values=[0.00944219809025526], datetime_start=datetime.datetime(2025, 1, 12, 12, 10, 2, 836939), datetime_complete=datetime.datetime(2025, 1, 12, 12, 10, 16, 6598), params={'num_layers': 3, 'hidden_channels': 32, 'gnn_type': 'gine', 'drop_ratio': 0.5, 'learning_rate': 0.06384524947866164}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=32, value=None),
#  FrozenTrial(number=32, state=1, values=[0.009359350427985191], datetime_start=datetime.datetime(2025, 1, 12, 12, 10, 16, 23926), datetime_complete=datetime.datetime(2025, 1, 12, 12, 10, 29, 432178), params={'num_layers': 2, 'hidden_channels': 32, 'gnn_type': 'gine', 'drop_ratio': 0.35000000000000003, 'learning_rate': 0.0038231261276025713}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=33, value=None),
#  FrozenTrial(number=33, state=1, values=[0.009351780638098717], datetime_start=datetime.datetime(2025, 1, 12, 12, 10, 29, 445145), datetime_complete=datetime.datetime(2025, 1, 12, 12, 10, 44, 730336), params={'num_layers': 2, 'hidden_channels': 128, 'gnn_type': 'gine', 'drop_ratio': 0.55, 'learning_rate': 0.0011964611055435292}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=34, value=None),
#  FrozenTrial(number=34, state=1, values=[0.05329279229044914], datetime_start=datetime.datetime(2025, 1, 12, 12, 10, 44, 748201), datetime_complete=datetime.datetime(2025, 1, 12, 12, 10, 58, 54743), params={'num_layers': 5, 'hidden_channels': 128, 'gnn_type': 'gine', 'drop_ratio': 0.5, 'learning_rate': 0.0011962860868400301}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=35, value=None),
#  FrozenTrial(number=35, state=1, values=[0.010098389349877834], datetime_start=datetime.datetime(2025, 1, 12, 12, 10, 58, 71439), datetime_complete=datetime.datetime(2025, 1, 12, 12, 11, 12, 467501), params={'num_layers': 3, 'hidden_channels': 128, 'gnn_type': 'gine', 'drop_ratio': 0.75, 'learning_rate': 0.007018722278735544}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=36, value=None),
#  FrozenTrial(number=36, state=1, values=[0.009914077818393707], datetime_start=datetime.datetime(2025, 1, 12, 12, 11, 12, 482817), datetime_complete=datetime.datetime(2025, 1, 12, 12, 11, 26, 358840), params={'num_layers': 3, 'hidden_channels': 64, 'gnn_type': 'gine', 'drop_ratio': 0.4, 'learning_rate': 0.07914467933295007}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=37, value=None),
#  FrozenTrial(number=37, state=1, values=[0.009145545773208141], datetime_start=datetime.datetime(2025, 1, 12, 12, 11, 26, 375807), datetime_complete=datetime.datetime(2025, 1, 12, 12, 11, 40, 599630), params={'num_layers': 2, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.25, 'learning_rate': 0.012787667961757667}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=38, value=None),
#  FrozenTrial(number=38, state=1, values=[0.01113645825535059], datetime_start=datetime.datetime(2025, 1, 12, 12, 11, 40, 613393), datetime_complete=datetime.datetime(2025, 1, 12, 12, 11, 55, 947817), params={'num_layers': 3, 'hidden_channels': 32, 'gnn_type': 'gine', 'drop_ratio': 0.8, 'learning_rate': 0.005461032368082971}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=39, value=None),
#  FrozenTrial(number=39, state=1, values=[0.009946991689503193], datetime_start=datetime.datetime(2025, 1, 12, 12, 11, 55, 960739), datetime_complete=datetime.datetime(2025, 1, 12, 12, 12, 12, 662342), params={'num_layers': 4, 'hidden_channels': 64, 'gnn_type': 'gine', 'drop_ratio': 0.75, 'learning_rate': 0.011148337016306796}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=40, value=None),
#  FrozenTrial(number=40, state=1, values=[0.01027070451527834], datetime_start=datetime.datetime(2025, 1, 12, 12, 12, 12, 676174), datetime_complete=datetime.datetime(2025, 1, 12, 12, 12, 29, 235981), params={'num_layers': 5, 'hidden_channels': 32, 'gnn_type': 'gine', 'drop_ratio': 0.45, 'learning_rate': 0.01399068770852125}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=41, value=None),
#  FrozenTrial(number=41, state=1, values=[0.009279869496822357], datetime_start=datetime.datetime(2025, 1, 12, 12, 12, 29, 259185), datetime_complete=datetime.datetime(2025, 1, 12, 12, 12, 43, 688356), params={'num_layers': 2, 'hidden_channels': 128, 'gnn_type': 'gine', 'drop_ratio': 0.65, 'learning_rate': 0.03503710492409185}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=42, value=None),
#  FrozenTrial(number=42, state=1, values=[0.009039943106472492], datetime_start=datetime.datetime(2025, 1, 12, 12, 12, 43, 711612), datetime_complete=datetime.datetime(2025, 1, 12, 12, 13, 0, 161883), params={'num_layers': 2, 'hidden_channels': 128, 'gnn_type': 'gine', 'drop_ratio': 0.4, 'learning_rate': 0.031839799508354305}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=43, value=None),
#  FrozenTrial(number=43, state=1, values=[0.009967031888663769], datetime_start=datetime.datetime(2025, 1, 12, 12, 13, 0, 175875), datetime_complete=datetime.datetime(2025, 1, 12, 12, 13, 18, 710250), params={'num_layers': 4, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.25, 'learning_rate': 0.05356987454995454}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=44, value=None),
#  FrozenTrial(number=44, state=1, values=[0.010734922252595425], datetime_start=datetime.datetime(2025, 1, 12, 12, 13, 18, 733354), datetime_complete=datetime.datetime(2025, 1, 12, 12, 13, 32, 639820), params={'num_layers': 3, 'hidden_channels': 32, 'gnn_type': 'gine', 'drop_ratio': 0.75, 'learning_rate': 0.0082692820061615}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=45, value=None),
#  FrozenTrial(number=45, state=1, values=[0.015726087614893913], datetime_start=datetime.datetime(2025, 1, 12, 12, 13, 32, 666654), datetime_complete=datetime.datetime(2025, 1, 12, 12, 13, 48, 816200), params={'num_layers': 4, 'hidden_channels': 32, 'gnn_type': 'gine', 'drop_ratio': 0.5, 'learning_rate': 0.0025125295168068576}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=46, value=None),
#  FrozenTrial(number=46, state=1, values=[0.009737111628055573], datetime_start=datetime.datetime(2025, 1, 12, 12, 13, 48, 830555), datetime_complete=datetime.datetime(2025, 1, 12, 12, 14, 6, 460361), params={'num_layers': 4, 'hidden_channels': 64, 'gnn_type': 'gine', 'drop_ratio': 0.45, 'learning_rate': 0.09731588993368957}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=47, value=None),
#  FrozenTrial(number=47, state=1, values=[0.009248336777091026], datetime_start=datetime.datetime(2025, 1, 12, 12, 14, 6, 487152), datetime_complete=datetime.datetime(2025, 1, 12, 12, 14, 21, 316339), params={'num_layers': 2, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.5, 'learning_rate': 0.015940083504959797}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=48, value=None),
#  FrozenTrial(number=48, state=1, values=[0.009635832160711288], datetime_start=datetime.datetime(2025, 1, 12, 12, 14, 21, 333785), datetime_complete=datetime.datetime(2025, 1, 12, 12, 14, 40, 569392), params={'num_layers': 4, 'hidden_channels': 64, 'gnn_type': 'gine', 'drop_ratio': 0.55, 'learning_rate': 0.028484421034040527}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=49, value=None),
#  FrozenTrial(number=49, state=1, values=[0.00881031434983015], datetime_start=datetime.datetime(2025, 1, 12, 12, 14, 40, 586743), datetime_complete=datetime.datetime(2025, 1, 12, 12, 14, 56, 926015), params={'num_layers': 3, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.5, 'learning_rate': 0.003895849663908143}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=50, value=None),
#  FrozenTrial(number=50, state=1, values=[0.009171909652650356], datetime_start=datetime.datetime(2025, 1, 12, 12, 15, 41, 225298), datetime_complete=datetime.datetime(2025, 1, 12, 12, 15, 56, 911339), params={'num_layers': 3, 'hidden_channels': 64, 'gnn_type': 'gine', 'drop_ratio': 0.45, 'learning_rate': 0.025462700141180128}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=51, value=None),
#  FrozenTrial(number=51, state=1, values=[0.010184617713093758], datetime_start=datetime.datetime(2025, 1, 12, 12, 15, 56, 939046), datetime_complete=datetime.datetime(2025, 1, 12, 12, 16, 14, 792078), params={'num_layers': 5, 'hidden_channels': 32, 'gnn_type': 'gine', 'drop_ratio': 0.35000000000000003, 'learning_rate': 0.002298208530700667}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=52, value=None),
#  FrozenTrial(number=52, state=1, values=[0.009768465533852577], datetime_start=datetime.datetime(2025, 1, 12, 12, 16, 14, 815407), datetime_complete=datetime.datetime(2025, 1, 12, 12, 16, 33, 44916), params={'num_layers': 5, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.65, 'learning_rate': 0.016523838095676195}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=53, value=None),
#  FrozenTrial(number=53, state=1, values=[0.008785341866314411], datetime_start=datetime.datetime(2025, 1, 12, 12, 16, 33, 69842), datetime_complete=datetime.datetime(2025, 1, 12, 12, 16, 45, 502001), params={'num_layers': 2, 'hidden_channels': 128, 'gnn_type': 'gine', 'drop_ratio': 0.45, 'learning_rate': 0.002151856756616884}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=54, value=None),
#  FrozenTrial(number=54, state=1, values=[0.010440009646117687], datetime_start=datetime.datetime(2025, 1, 12, 12, 16, 45, 530199), datetime_complete=datetime.datetime(2025, 1, 12, 12, 16, 59, 928798), params={'num_layers': 4, 'hidden_channels': 32, 'gnn_type': 'gine', 'drop_ratio': 0.65, 'learning_rate': 0.010325786257039714}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=55, value=None),
#  FrozenTrial(number=55, state=1, values=[0.009391100145876408], datetime_start=datetime.datetime(2025, 1, 12, 12, 16, 59, 951754), datetime_complete=datetime.datetime(2025, 1, 12, 12, 17, 18, 724379), params={'num_layers': 5, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.30000000000000004, 'learning_rate': 0.0031976961356619863}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=56, value=None),
#  FrozenTrial(number=56, state=1, values=[0.00961581151932478], datetime_start=datetime.datetime(2025, 1, 12, 12, 17, 18, 740246), datetime_complete=datetime.datetime(2025, 1, 12, 12, 17, 32, 313379), params={'num_layers': 3, 'hidden_channels': 128, 'gnn_type': 'gine', 'drop_ratio': 0.45, 'learning_rate': 0.058777141082716915}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=57, value=None),
#  FrozenTrial(number=57, state=1, values=[0.009965827688574791], datetime_start=datetime.datetime(2025, 1, 12, 12, 17, 32, 332647), datetime_complete=datetime.datetime(2025, 1, 12, 12, 17, 49, 999111), params={'num_layers': 4, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.35000000000000003, 'learning_rate': 0.05518664508362426}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=58, value=None),
#  FrozenTrial(number=58, state=1, values=[0.010178234428167343], datetime_start=datetime.datetime(2025, 1, 12, 12, 17, 50, 22474), datetime_complete=datetime.datetime(2025, 1, 12, 12, 18, 8, 326375), params={'num_layers': 5, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.35000000000000003, 'learning_rate': 0.006911661262642869}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=59, value=None),
#  FrozenTrial(number=59, state=1, values=[0.010289077647030354], datetime_start=datetime.datetime(2025, 1, 12, 12, 18, 8, 344745), datetime_complete=datetime.datetime(2025, 1, 12, 12, 18, 24, 464769), params={'num_layers': 4, 'hidden_channels': 64, 'gnn_type': 'gine', 'drop_ratio': 0.6000000000000001, 'learning_rate': 0.009396518031066056}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=60, value=None),
#  FrozenTrial(number=60, state=1, values=[0.010042528621852398], datetime_start=datetime.datetime(2025, 1, 12, 12, 18, 24, 489081), datetime_complete=datetime.datetime(2025, 1, 12, 12, 18, 40, 21674), params={'num_layers': 3, 'hidden_channels': 64, 'gnn_type': 'gine', 'drop_ratio': 0.8, 'learning_rate': 0.07928682062669623}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=61, value=None),
#  FrozenTrial(number=61, state=1, values=[0.010472907684743404], datetime_start=datetime.datetime(2025, 1, 12, 12, 18, 40, 44551), datetime_complete=datetime.datetime(2025, 1, 12, 12, 18, 58, 809952), params={'num_layers': 5, 'hidden_channels': 64, 'gnn_type': 'gine', 'drop_ratio': 0.45, 'learning_rate': 0.0036251055388621563}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=62, value=None),
# ...
#  FrozenTrial(number=80, state=1, values=[0.009153389371931553], datetime_start=datetime.datetime(2025, 1, 12, 12, 25, 2, 109137), datetime_complete=datetime.datetime(2025, 1, 12, 12, 25, 18, 246771), params={'num_layers': 4, 'hidden_channels': 128, 'gnn_type': 'gine', 'drop_ratio': 0.2, 'learning_rate': 0.016565802254396442}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=81, value=None),
#  FrozenTrial(number=81, state=1, values=[0.009939495474100113], datetime_start=datetime.datetime(2025, 1, 12, 12, 25, 18, 270984), datetime_complete=datetime.datetime(2025, 1, 12, 12, 25, 34, 53241), params={'num_layers': 4, 'hidden_channels': 128, 'gnn_type': 'gine', 'drop_ratio': 0.75, 'learning_rate': 0.033562965986090945}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=82, value=None),
#  FrozenTrial(number=82, state=1, values=[0.009952513501048088], datetime_start=datetime.datetime(2025, 1, 12, 12, 25, 34, 76619), datetime_complete=datetime.datetime(2025, 1, 12, 12, 25, 52, 38257), params={'num_layers': 4, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.45, 'learning_rate': 0.002391177769243444}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=83, value=None),
#  FrozenTrial(number=83, state=1, values=[0.013340580277144909], datetime_start=datetime.datetime(2025, 1, 12, 12, 25, 52, 52699), datetime_complete=datetime.datetime(2025, 1, 12, 12, 26, 7, 748141), params={'num_layers': 4, 'hidden_channels': 128, 'gnn_type': 'gine', 'drop_ratio': 0.6000000000000001, 'learning_rate': 0.002069021529483894}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=84, value=None),
#  FrozenTrial(number=84, state=1, values=[0.009766505099833012], datetime_start=datetime.datetime(2025, 1, 12, 12, 26, 7, 778680), datetime_complete=datetime.datetime(2025, 1, 12, 12, 26, 26, 273339), params={'num_layers': 5, 'hidden_channels': 128, 'gnn_type': 'gine', 'drop_ratio': 0.7, 'learning_rate': 0.07244682868651812}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=85, value=None),
#  FrozenTrial(number=85, state=1, values=[0.009442148730158806], datetime_start=datetime.datetime(2025, 1, 12, 12, 26, 26, 295373), datetime_complete=datetime.datetime(2025, 1, 12, 12, 26, 46, 410066), params={'num_layers': 5, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.5, 'learning_rate': 0.02165603123470428}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=86, value=None),
#  FrozenTrial(number=86, state=1, values=[0.011576443910598755], datetime_start=datetime.datetime(2025, 1, 12, 12, 26, 46, 427343), datetime_complete=datetime.datetime(2025, 1, 12, 12, 27, 1, 573224), params={'num_layers': 3, 'hidden_channels': 32, 'gnn_type': 'gine', 'drop_ratio': 0.7, 'learning_rate': 0.0027407383894302285}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=87, value=None),
#  FrozenTrial(number=87, state=1, values=[0.009881545789539814], datetime_start=datetime.datetime(2025, 1, 12, 12, 27, 1, 586659), datetime_complete=datetime.datetime(2025, 1, 12, 12, 27, 19, 533692), params={'num_layers': 4, 'hidden_channels': 64, 'gnn_type': 'gine', 'drop_ratio': 0.6000000000000001, 'learning_rate': 0.06124657904852314}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=88, value=None),
#  FrozenTrial(number=88, state=1, values=[0.009904335252940655], datetime_start=datetime.datetime(2025, 1, 12, 12, 27, 19, 560155), datetime_complete=datetime.datetime(2025, 1, 12, 12, 27, 38, 449522), params={'num_layers': 4, 'hidden_channels': 64, 'gnn_type': 'gine', 'drop_ratio': 0.8, 'learning_rate': 0.08504886489264303}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=89, value=None),
#  FrozenTrial(number=89, state=1, values=[0.009496496990323067], datetime_start=datetime.datetime(2025, 1, 12, 12, 27, 38, 472841), datetime_complete=datetime.datetime(2025, 1, 12, 12, 27, 53, 96918), params={'num_layers': 2, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.35000000000000003, 'learning_rate': 0.05028955916238403}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=90, value=None),
#  FrozenTrial(number=90, state=1, values=[0.009947416372597218], datetime_start=datetime.datetime(2025, 1, 12, 12, 28, 31, 373698), datetime_complete=datetime.datetime(2025, 1, 12, 12, 28, 46, 184895), params={'num_layers': 3, 'hidden_channels': 64, 'gnn_type': 'gine', 'drop_ratio': 0.75, 'learning_rate': 0.047964449192500674}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=91, value=None),
#  FrozenTrial(number=91, state=1, values=[0.010007060132920742], datetime_start=datetime.datetime(2025, 1, 12, 12, 28, 46, 211423), datetime_complete=datetime.datetime(2025, 1, 12, 12, 29, 6, 503467), params={'num_layers': 5, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.75, 'learning_rate': 0.03979212287759095}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=92, value=None),
#  FrozenTrial(number=92, state=1, values=[0.009773573838174343], datetime_start=datetime.datetime(2025, 1, 12, 12, 29, 6, 520051), datetime_complete=datetime.datetime(2025, 1, 12, 12, 29, 21, 430549), params={'num_layers': 4, 'hidden_channels': 128, 'gnn_type': 'gine', 'drop_ratio': 0.55, 'learning_rate': 0.011511303267921158}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=93, value=None),
#  FrozenTrial(number=93, state=1, values=[0.009965392760932446], datetime_start=datetime.datetime(2025, 1, 12, 12, 29, 21, 453794), datetime_complete=datetime.datetime(2025, 1, 12, 12, 29, 39, 970062), params={'num_layers': 5, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.7, 'learning_rate': 0.0448412385875734}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=94, value=None),
#  FrozenTrial(number=94, state=1, values=[0.00917631946504116], datetime_start=datetime.datetime(2025, 1, 12, 12, 29, 39, 993215), datetime_complete=datetime.datetime(2025, 1, 12, 12, 29, 52, 556237), params={'num_layers': 2, 'hidden_channels': 128, 'gnn_type': 'gine', 'drop_ratio': 0.5, 'learning_rate': 0.0021904838038442993}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=95, value=None),
#  FrozenTrial(number=95, state=1, values=[0.010124130174517632], datetime_start=datetime.datetime(2025, 1, 12, 12, 29, 52, 581829), datetime_complete=datetime.datetime(2025, 1, 12, 12, 30, 8, 767236), params={'num_layers': 5, 'hidden_channels': 128, 'gnn_type': 'gine', 'drop_ratio': 0.6000000000000001, 'learning_rate': 0.008771393187372446}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=96, value=None),
#  FrozenTrial(number=96, state=1, values=[0.008770616725087166], datetime_start=datetime.datetime(2025, 1, 12, 12, 30, 8, 791595), datetime_complete=datetime.datetime(2025, 1, 12, 12, 30, 24, 280413), params={'num_layers': 3, 'hidden_channels': 256, 'gnn_type': 'gine', 'drop_ratio': 0.2, 'learning_rate': 0.025118837737807587}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=97, value=None),
#  FrozenTrial(number=97, state=1, values=[0.009851986542344093], datetime_start=datetime.datetime(2025, 1, 12, 12, 30, 24, 303653), datetime_complete=datetime.datetime(2025, 1, 12, 12, 30, 43, 734166), params={'num_layers': 5, 'hidden_channels': 64, 'gnn_type': 'gine', 'drop_ratio': 0.2, 'learning_rate': 0.001976508744960422}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=98, value=None),
#  FrozenTrial(number=98, state=1, values=[0.009673717431724072], datetime_start=datetime.datetime(2025, 1, 12, 12, 30, 43, 760606), datetime_complete=datetime.datetime(2025, 1, 12, 12, 30, 58, 176421), params={'num_layers': 2, 'hidden_channels': 64, 'gnn_type': 'gine', 'drop_ratio': 0.65, 'learning_rate': 0.048892188406806966}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=99, value=None),
#  FrozenTrial(number=99, state=1, values=[0.010756746865808964], datetime_start=datetime.datetime(2025, 1, 12, 12, 30, 58, 191058), datetime_complete=datetime.datetime(2025, 1, 12, 12, 31, 13, 875183), params={'num_layers': 2, 'hidden_channels': 64, 'gnn_type': 'gine', 'drop_ratio': 0.45, 'learning_rate': 0.0013937408962423387}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=5, log=False, low=2, step=1), 'hidden_channels': CategoricalDistribution(choices=(32, 64, 128, 256)), 'gnn_type': CategoricalDistribution(choices=('gine',)), 'drop_ratio': FloatDistribution(high=0.8, log=False, low=0.2, step=0.05), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=100, value=None)]

# %%
best = study.best_trial
print(f'Best model: {best.number}')
print(f'Best validation loss: {best.value:.5f}')
print(f'-----')
for key, value in best.params.items():
    print('{}: {}'.format(key, value))
# Out:
# Best model: 77
# Best validation loss: 0.00850
# -----
# num_layers: 4
# hidden_channels: 256
# gnn_type: gine
# drop_ratio: 0.25
# learning_rate: 0.002757492781410889

# %%
import pandas

df = test_study.trials_dataframe(attrs=('number', 'value', 'params', 'state'))

# %%
df
# Out:
#     number     value  params_drop_ratio params_gnn_type  \
# 0        0  0.010422               0.45             gcn
# 1        1  0.008256               0.20             gcn
# 2        2  0.009264               0.60             gcn
# 3        3  0.008699               0.25             gcn
# 4        4  0.009529               0.75             gcn
# ..     ...       ...                ...             ...
# 95      95  0.009642               0.30             gcn
# 96      96  0.011894               0.50             gcn
# 97      97  0.010100               0.50             gcn
# 98      98  0.010322               0.70             gcn
# 99      99  0.010366               0.75             gcn
#
#     params_hidden_channels  params_learning_rate  params_num_layers     state
# 0                      256              0.043269                  3  COMPLETE
# 1                      128              0.014889                  4  COMPLETE
# 2                      128              0.001206                  2  COMPLETE
# 3                      256              0.015071                  4  COMPLETE
# 4                       32              0.033969                  2  COMPLETE
# ..                     ...                   ...                ...       ...
# 95                      64              0.001690                  3  COMPLETE
# 96                     256              0.089703                  3  COMPLETE
# 97                      64              0.002630                  4  COMPLETE
# 98                      64              0.004225                  5  COMPLETE
# 99                     256              0.021791                  5  COMPLETE
#
# [100 rows x 8 columns]

# %%
test = trainer.test(model, test_loader, ckpt_path='best')
# Out:
# Restoring states from the checkpoint path at ./lightning_logs/version_9/checkpoints/val_loss=0.007806-epoch=80.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at ./lightning_logs/version_9/checkpoints/val_loss=0.007806-epoch=80.ckpt
# /home/samjhall/miniconda3/envs/pyg-schnet/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:424: The 'test_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=23` in the `DataLoader` to improve performance.
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_MSE          │   0.008015623316168785    │
# │         test_RSE          │   0.006631326396018267    │
# └───────────────────────────┴───────────────────────────┘

# %%
results = trainer.predict(model, test_loader)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/samjhall/miniconda3/envs/pyg-schnet/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:424: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=23` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]

# %%
import matplotlib.pyplot as plt

plt.plot(results[0][0][0])
plt.plot(results[0][1][0])
plt.show()

# %%
import numpy as np
def calculate_rse(prediction, true_result):
    
    del_E = 20 / len(prediction)

    numerator = np.sum(del_E * np.power((true_result - prediction),2))

    denominator = np.sum(del_E * true_result)

    return np.sqrt(numerator) / denominator

# %%
from utils.functions import RSE_loss
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(results[0][0][0], results[0][1][0])

rse = calculate_rse(results[0][0][0], results[0][1][0])

# %%
mse
# Out:
# np.float32(0.009946687)

# %%
rse
# Out:
# np.float32(0.04524091)

# %%
len(results[0][0])
# Out:
# 39

# %%
rse_values = []
mse_values = []

for x in range(len(results[0][0])):
    rse = calculate_rse(results[0][0][x], results[0][1][x])
    mse = mean_squared_error(results[0][0][x], results[0][1][x])
    rse_values.append(float(rse))
    mse_values.append(mse)

# %%
rse_values
# Out:
# [0.04524090886116028,
#  0.03138181194663048,
#  0.03464198857545853,
#  0.0470629520714283,
#  0.06860910356044769,
#  0.04022042453289032,
#  0.04248536750674248,
#  0.022021129727363586,
#  0.045649606734514236,
#  0.04109703749418259,
#  0.04154657945036888,
#  0.044713061302900314,
#  0.032572340220212936,
#  0.02955792471766472,
#  0.0258046742528677,
#  0.04395646974444389,
#  0.0481165386736393,
#  0.038175810128450394,
#  0.023417241871356964,
#  0.055591534823179245,
#  0.037764038890600204,
#  0.04689478129148483,
#  0.03165239095687866,
#  0.023253560066223145,
#  0.02590259350836277,
#  0.028880665078759193,
#  0.03935161605477333,
#  0.06465158611536026,
#  0.02560332790017128,
#  0.03482656553387642,
#  0.04475194960832596,
#  0.04192739352583885,
#  0.021364597603678703,
#  0.026672741398215294,
#  0.04156876727938652,
#  0.049255214631557465,
#  0.031399521976709366,
#  0.058007918298244476,
#  0.0615413635969162]

# %%
print(rse_values.index(min(rse_values)))
print(mse_values.index(min(mse_values)))
# Out:
# 32
# 7

# %%
min(rse_values)
# Out:
# 0.021364597603678703

# %%
sum(rse_values) / len(rse_values)
# Out:
# 0.039413669218237586

# %%
sum(mse_values) / len(mse_values)
# Out:
# np.float32(0.008015625)
